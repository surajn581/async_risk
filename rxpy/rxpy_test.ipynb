# %%
from rxpy import main

# %%
await main()
# Out:
# 2025-08-17 00:22:34.372India Standard Time 32080 INFO Processing 3 prices...
# 2025-08-17 00:22:34.374India Standard Time 32080 INFO Price ticked: 100.0
# 2025-08-17 00:22:34.376India Standard Time 32080 INFO Price ticked: 101.0
# 2025-08-17 00:22:34.376India Standard Time 32080 INFO Price ticked: 102.0
# 2025-08-17 00:22:34.376India Standard Time 32080 INFO Processing 2 market_moves...
# 2025-08-17 00:22:34.376India Standard Time 32080 INFO Market move ticked: 0.97
# 2025-08-17 00:22:34.376India Standard Time 32080 INFO Predicts: [97.0, 97.97, 98.94]
# 2025-08-17 00:22:34.376India Standard Time 32080 INFO Market move ticked: 0.96
# 2025-08-17 00:22:34.376India Standard Time 32080 INFO No prices to process, updating market move: 0.96 in state
# 2025-08-17 00:22:34.488India Standard Time 32080 INFO Processing 3 prices...
# 2025-08-17 00:22:34.491India Standard Time 32080 INFO Price ticked: 105.0
# 2025-08-17 00:22:34.492India Standard Time 32080 INFO Re-ticking market move 0.96
# ...
