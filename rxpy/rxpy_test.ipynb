# %%
from rxpy import main

# %%
error = None
try:
    await main()
except Exception as ex:
    error = ex
# Out:
# 2025-08-17 04:36:11.942India Standard Time 28004 33044 INFO Processing 1 prices...
# 2025-08-17 04:36:11.944India Standard Time 28004 33044 INFO Price ticked: 100.0
# 2025-08-17 04:36:11.944India Standard Time 28004 33044 INFO Re-ticking market move 0.89
# 2025-08-17 04:36:11.945India Standard Time 28004 33044 INFO Market move ticked: 0.89
# 2025-08-17 04:36:11.946India Standard Time 28004 33044 INFO Predicts: [89.0]
# 2025-08-17 04:36:11.946India Standard Time 28004 33044 INFO Predicts: [89.0]
# 2025-08-17 04:36:11.947India Standard Time 28004 33044 INFO Market move ticked: 0.89
# 2025-08-17 04:36:11.947India Standard Time 28004 33044 INFO No prices to process
# 2025-08-17 04:36:11.948India Standard Time 28004 33044 INFO Price ticked: 100.0
# 2025-08-17 04:36:11.950India Standard Time 28004 33044 INFO Re-ticking market move 0.89
# 2025-08-17 04:36:11.950India Standard Time 28004 33044 INFO Market move ticked: 0.89
# ...

# %%
import async_io
