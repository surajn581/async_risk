# %%
import ast
import inspect
from lib.logging import logger

# %%
import time
from graph import Graph, GraphNode

# %%
class Node:
    def __init__(self, settable=True):
        self._settable = settable
        self._cachedValue = None

    def __call__(self, func):
        
        def wrapper(*args, **kwargs):
            if not self._cachedValue:
                self._cachedValue = func(*args, **kwargs)
            return self._cachedValue
        
        if self._settable:
            def setter(value):
                logger.info(f'Setting value of Node: {func.__name__} = {value}')
                self._cachedValue = value
            wrapper.set = setter

        def delete():
            logger.info(f'Clearing value of Node: {func.__name__}')
            self._cachedValue = None
        wrapper.delete = delete
        
        return wrapper


@Node(settable=True)
def A():
    logger.info('expensive fn called')
    time.sleep(2)
    return 1

# %%
class Test:
    def __init__(self):
        self.a = 'a'

    def A(self):
        return 1

node = GraphNode(Test.A, settable=True)

# %%
Test.A.__get__()
# Out:
# <method-wrapper '__get__' of function object at 0x000001941261ACA0>

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20828/3463037537.py in <module>
#       1 import hashlib
# ----> 2 hash([], {})
#
# TypeError: hash() takes exactly one argument (2 given)

# %%
from graph import MyGraph, graph_node
g = MyGraph()
# Out:
# 2025-08-11 22:45:34.650India Standard Time 20828 DEBUG [MyGraph] __init__ start
# 2025-08-11 22:45:34.653India Standard Time 20828 DEBUG [Graph] __init__ start
# 2025-08-11 22:45:34.654India Standard Time 20828 DEBUG [Graph] __init__ end
# 2025-08-11 22:45:34.655India Standard Time 20828 DEBUG [MyGraph] __init__ end

# %%
g.A.set
# Out:
# <function graph.GraphNode.__get__.<locals>.setter(value)>

# %%
dg = g.getDependencyGraph()
dg
# Out:
# {'A': set(),
#  'B': {'A'},
#  'C': {'A', 'B'},
#  'D': {'A', 'B'},
#  'E': {'A', 'B', 'D'},
#  'F': {'A', 'B', 'D', 'E'}}

# %%
g.getReverseDependencyGraph()
# Out:
# {'A': {'B', 'C', 'D', 'E', 'F'},
#  'B': {'C', 'D', 'E', 'F'},
#  'D': {'E', 'F'},
#  'E': {'F'}}

# %%
src = inspect.getsource(g.__class__)
print(src)
# Out:
# class MyGraph(Graph):
#     def __init__(self):
#         logger.debug('[MyGraph] __init__ start')
#         super().__init__()
#         logger.debug('[MyGraph] __init__ end')
#
#     @graph_node(settable=True)
#     def A(self):
#         logger.debug('[MyGraph] graph_node A called')
#         return 10
#
#     @graph_node()
#     def B(self):
#         logger.debug('[MyGraph] graph_node B called')
#         return self.A() ** 2
#
#     @graph_node()
#     def C(self):
#         logger.debug('[MyGraph] graph_node C called')
#         return self.B() + self.A()
#
#     @graph_node()
#     def D(self, value):
#         logger.debug('[MyGraph] graph_node D called')
#         return value*self.B()
#
#     @graph_node()
#     def E(self):
#         logger.debug('[MyGraph] graph_node E called')
#         return self.D( self.A() ) * 2
#
#     @graph_node()
#     def F(self):
#         logger.debug('[MyGraph] graph_node F called')
#         if self.A() > 5:
#             return self.E()*1.5
#         else:
#             return self.D(5)

# %%
tree = ast.parse(src)

# %%
nodes = []
for node in ast.walk(tree):
    if isinstance(node, ast.FunctionDef):
        nodes.append(node)

# %%
b = nodes[2]

# %%
for decor in b.decorator_list:
    if decor.func.id == 'graph_node':
        print(True)
# Out:
# True

# %%
from collections import deque

def expand_dependencies_optimized(graph):
    graph = {k: set(v) for k, v in graph.items()}        
    nodesToExpand = deque(graph.keys())

    while nodesToExpand:
        node = nodesToExpand.popleft()
        current_deps = graph[node].copy()

        for dep in current_deps:
            new_items = graph[dep].difference(current_deps)
            if not new_items:
                continue
            graph[node].update(new_items)
            nodesToExpand.append(node)
    
    return graph

# %%
def getDependencyGraphFromTree(tree):
    dependency_graph = {}
    for node in ast.walk(tree):
        if not any(decor.func.id == graph_node.__name__ for decor in getattr(node, 'decorator_list', [])):
            continue
        dependency_graph[node.name] = set()
        for inner_node in node.body:
            for _n in ast.walk(inner_node):
                if isinstance(_n, ast.Attribute) and _n.value.id=='self':
                    dependency_graph[node.name].add(_n.attr)

    return dependency_graph

def getDependencyGraphFromClass(cls):
    src = inspect.getsource(cls)
    tree = ast.parse(src)
    return getDependencyGraphFromTree(tree)

# %%
dep = getDependencyGraphFromClass(g.__class__)
dep
# Out:
# {'A': set(),
#  'B': {'A'},
#  'C': {'A', 'B'},
#  'D': {'B'},
#  'E': {'A', 'D'},
#  'F': {'A', 'D', 'E'}}

# %%
expand_dependencies_optimized(dep)
# Out:
# {'A': set(),
#  'B': {'A'},
#  'C': {'A', 'B'},
#  'D': {'A', 'B'},
#  'E': {'A', 'B', 'D'},
#  'F': {'A', 'B', 'D', 'E'}}

# %%
for node in ast.walk(tree):
    if not any(decor.func.id == 'graph_node' for decor in getattr(node, 'decorator_list', [])):
        continue
    print(node.name, '--------------')
    for inner_node in node.body:
        print('\t', inner_node.__class__.__name__)
        for _n in ast.walk(inner_node):
            if isinstance(_n, ast.Attribute):
                print('\t\t', _n.value.id, _n.attr)
# Out:
# A --------------
# 	 Expr
# 		 logger debug
# 	 Return
# B --------------
# 	 Expr
# 		 logger debug
# 	 Return
# 		 self A
# C --------------
# 	 Expr
# 		 logger debug
# 	 Return
# 		 self B
# 		 self A
# D --------------
# 	 Expr
# 		 logger debug
# 	 Return
# 		 self B
# E --------------
# 	 Expr
# 		 logger debug
# 	 Return
# 		 self D
# 		 self A
# F --------------
# 	 Expr
# 		 logger debug
# 	 If
# 		 self A
# 		 self D
# 		 self E

# %%
inner_node.orelse

# %%
b_body = b.body[0]
b_return = b.body[1]

# %%
b_return.__class__.__name__
# Out:
# 'Return'

# %%
b_body.value.func.value.

# %%
for n in ast.walk(b.body[1]):
    if isinstance(n, ast.Attribute):
        print(n.attr)
# Out:
# A

# %%
baa = b.args.args[0]

# %%
b_return.value.left.func.value.id
# Out:
# 'self'

# %%
# Pretty-print AST
astpretty.pprint(tree)
# Out:
# Module(
#     body=[
#         ClassDef(
#             lineno=1,
#             col_offset=0,
#             end_lineno=38,
#             end_col_offset=21,
#             name='MyGraph',
#             bases=[Name(lineno=1, col_offset=14, end_lineno=1, end_col_offset=19, id='Graph', ctx=Load())],
#             keywords=[],
#             body=[
#                 FunctionDef(
#                     lineno=2,
#                     col_offset=4,
#                     end_lineno=5,
#                     end_col_offset=46,
#                     name='__init__',
#                     args=arguments(
#                         posonlyargs=[],
#                         args=[arg(lineno=2, col_offset=17, end_lineno=2, end_col_offset=21, arg='self', annotation=None, type_comment=None)],
#                         vararg=None,
#                         kwonlyargs=[],
#                         kw_defaults=[],
#                         kwarg=None,
#                         defaults=[],
#                     ),
#                     body=[
#                         Expr(
#                             lineno=3,
#                             col_offset=8,
#                             end_lineno=3,
#                             end_col_offset=48,
#                             value=Call(
#                                 lineno=3,
#                                 col_offset=8,
#                                 end_lineno=3,
#                                 end_col_offset=48,
#                                 func=Attribute(
#                                     lineno=3,
#                                     col_offset=8,
#                                     end_lineno=3,
#                                     end_col_offset=20,
#                                     value=Name(lineno=3, col_offset=8, end_lineno=3, end_col_offset=14, id='logger', ctx=Load()),
#                                     attr='debug',
#                                     ctx=Load(),
#                                 ),
#                                 args=[Constant(lineno=3, col_offset=21, end_lineno=3, end_col_offset=47, value='[MyGraph] __init__ start', kind=None)],
#                                 keywords=[],
#                             ),
#                         ),
#                         Expr(
#                             lineno=4,
#                             col_offset=8,
#                             end_lineno=4,
#                             end_col_offset=26,
#                             value=Call(
#                                 lineno=4,
#                                 col_offset=8,
#                                 end_lineno=4,
#                                 end_col_offset=26,
#                                 func=Attribute(
#                                     lineno=4,
#                                     col_offset=8,
#                                     end_lineno=4,
#                                     end_col_offset=24,
#                                     value=Call(
#                                         lineno=4,
#                                         col_offset=8,
#                                         end_lineno=4,
#                                         end_col_offset=15,
#                                         func=Name(lineno=4, col_offset=8, end_lineno=4, end_col_offset=13, id='super', ctx=Load()),
#                                         args=[],
#                                         keywords=[],
#                                     ),
#                                     attr='__init__',
#                                     ctx=Load(),
#                                 ),
#                                 args=[],
#                                 keywords=[],
#                             ),
#                         ),
#                         Expr(
#                             lineno=5,
#                             col_offset=8,
#                             end_lineno=5,
#                             end_col_offset=46,
#                             value=Call(
#                                 lineno=5,
#                                 col_offset=8,
#                                 end_lineno=5,
#                                 end_col_offset=46,
#                                 func=Attribute(
#                                     lineno=5,
#                                     col_offset=8,
#                                     end_lineno=5,
#                                     end_col_offset=20,
#                                     value=Name(lineno=5, col_offset=8, end_lineno=5, end_col_offset=14, id='logger', ctx=Load()),
#                                     attr='debug',
#                                     ctx=Load(),
#                                 ),
#                                 args=[Constant(lineno=5, col_offset=21, end_lineno=5, end_col_offset=45, value='[MyGraph] __init__ end', kind=None)],
#                                 keywords=[],
#                             ),
#                         ),
#                     ],
#                     decorator_list=[],
#                     returns=None,
#                     type_comment=None,
#                 ),
#                 FunctionDef(
#                     lineno=8,
#                     col_offset=4,
#                     end_lineno=10,
#                     end_col_offset=17,
#                     name='A',
#                     args=arguments(
#                         posonlyargs=[],
#                         args=[arg(lineno=8, col_offset=10, end_lineno=8, end_col_offset=14, arg='self', annotation=None, type_comment=None)],
#                         vararg=None,
#                         kwonlyargs=[],
#                         kw_defaults=[],
#                         kwarg=None,
#                         defaults=[],
#                     ),
#                     body=[
#                         Expr(
#                             lineno=9,
#                             col_offset=8,
#                             end_lineno=9,
#                             end_col_offset=53,
#                             value=Call(
#                                 lineno=9,
#                                 col_offset=8,
#                                 end_lineno=9,
#                                 end_col_offset=53,
#                                 func=Attribute(
#                                     lineno=9,
#                                     col_offset=8,
#                                     end_lineno=9,
#                                     end_col_offset=20,
#                                     value=Name(lineno=9, col_offset=8, end_lineno=9, end_col_offset=14, id='logger', ctx=Load()),
#                                     attr='debug',
#                                     ctx=Load(),
#                                 ),
#                                 args=[Constant(lineno=9, col_offset=21, end_lineno=9, end_col_offset=52, value='[MyGraph] graph_node A called', kind=None)],
#                                 keywords=[],
#                             ),
#                         ),
#                         Return(
#                             lineno=10,
#                             col_offset=8,
#                             end_lineno=10,
#                             end_col_offset=17,
#                             value=Constant(lineno=10, col_offset=15, end_lineno=10, end_col_offset=17, value=10, kind=None),
#                         ),
#                     ],
#                     decorator_list=[
#                         Call(
#                             lineno=7,
#                             col_offset=5,
#                             end_lineno=7,
#                             end_col_offset=30,
#                             func=Name(lineno=7, col_offset=5, end_lineno=7, end_col_offset=15, id='graph_node', ctx=Load()),
#                             args=[],
#                             keywords=[
#                                 keyword(
#                                     arg='settable',
#                                     value=Constant(lineno=7, col_offset=25, end_lineno=7, end_col_offset=29, value=True, kind=None),
#                                 ),
#                             ],
#                         ),
#                     ],
#                     returns=None,
#                     type_comment=None,
#                 ),
#                 FunctionDef(
#                     lineno=13,
#                     col_offset=4,
#                     end_lineno=15,
#                     end_col_offset=28,
#                     name='B',
#                     args=arguments(
#                         posonlyargs=[],
#                         args=[arg(lineno=13, col_offset=10, end_lineno=13, end_col_offset=14, arg='self', annotation=None, type_comment=None)],
#                         vararg=None,
#                         kwonlyargs=[],
#                         kw_defaults=[],
#                         kwarg=None,
#                         defaults=[],
#                     ),
#                     body=[
#                         Expr(
#                             lineno=14,
#                             col_offset=8,
#                             end_lineno=14,
#                             end_col_offset=53,
#                             value=Call(
#                                 lineno=14,
#                                 col_offset=8,
#                                 end_lineno=14,
#                                 end_col_offset=53,
#                                 func=Attribute(
#                                     lineno=14,
#                                     col_offset=8,
#                                     end_lineno=14,
#                                     end_col_offset=20,
#                                     value=Name(lineno=14, col_offset=8, end_lineno=14, end_col_offset=14, id='logger', ctx=Load()),
#                                     attr='debug',
#                                     ctx=Load(),
#                                 ),
#                                 args=[Constant(lineno=14, col_offset=21, end_lineno=14, end_col_offset=52, value='[MyGraph] graph_node B called', kind=None)],
#                                 keywords=[],
#                             ),
#                         ),
#                         Return(
#                             lineno=15,
#                             col_offset=8,
#                             end_lineno=15,
#                             end_col_offset=28,
#                             value=BinOp(
#                                 lineno=15,
#                                 col_offset=15,
#                                 end_lineno=15,
#                                 end_col_offset=28,
#                                 left=Call(
#                                     lineno=15,
#                                     col_offset=15,
#                                     end_lineno=15,
#                                     end_col_offset=23,
#                                     func=Attribute(
#                                         lineno=15,
#                                         col_offset=15,
#                                         end_lineno=15,
#                                         end_col_offset=21,
#                                         value=Name(lineno=15, col_offset=15, end_lineno=15, end_col_offset=19, id='self', ctx=Load()),
#                                         attr='A',
#                                         ctx=Load(),
#                                     ),
#                                     args=[],
#                                     keywords=[],
#                                 ),
#                                 op=Pow(),
#                                 right=Constant(lineno=15, col_offset=27, end_lineno=15, end_col_offset=28, value=2, kind=None),
#                             ),
#                         ),
#                     ],
#                     decorator_list=[
#                         Call(
#                             lineno=12,
#                             col_offset=5,
#                             end_lineno=12,
#                             end_col_offset=17,
#                             func=Name(lineno=12, col_offset=5, end_lineno=12, end_col_offset=15, id='graph_node', ctx=Load()),
#                             args=[],
#                             keywords=[],
#                         ),
#                     ],
#                     returns=None,
#                     type_comment=None,
#                 ),
#                 FunctionDef(
#                     lineno=18,
#                     col_offset=4,
#                     end_lineno=20,
#                     end_col_offset=34,
#                     name='C',
#                     args=arguments(
#                         posonlyargs=[],
#                         args=[arg(lineno=18, col_offset=10, end_lineno=18, end_col_offset=14, arg='self', annotation=None, type_comment=None)],
#                         vararg=None,
#                         kwonlyargs=[],
#                         kw_defaults=[],
#                         kwarg=None,
#                         defaults=[],
#                     ),
#                     body=[
#                         Expr(
#                             lineno=19,
#                             col_offset=8,
#                             end_lineno=19,
#                             end_col_offset=53,
#                             value=Call(
#                                 lineno=19,
#                                 col_offset=8,
#                                 end_lineno=19,
#                                 end_col_offset=53,
#                                 func=Attribute(
#                                     lineno=19,
#                                     col_offset=8,
#                                     end_lineno=19,
#                                     end_col_offset=20,
#                                     value=Name(lineno=19, col_offset=8, end_lineno=19, end_col_offset=14, id='logger', ctx=Load()),
#                                     attr='debug',
#                                     ctx=Load(),
#                                 ),
#                                 args=[Constant(lineno=19, col_offset=21, end_lineno=19, end_col_offset=52, value='[MyGraph] graph_node C called', kind=None)],
#                                 keywords=[],
#                             ),
#                         ),
#                         Return(
#                             lineno=20,
#                             col_offset=8,
#                             end_lineno=20,
#                             end_col_offset=34,
#                             value=BinOp(
#                                 lineno=20,
#                                 col_offset=15,
#                                 end_lineno=20,
#                                 end_col_offset=34,
#                                 left=Call(
#                                     lineno=20,
#                                     col_offset=15,
#                                     end_lineno=20,
#                                     end_col_offset=23,
#                                     func=Attribute(
#                                         lineno=20,
#                                         col_offset=15,
#                                         end_lineno=20,
#                                         end_col_offset=21,
#                                         value=Name(lineno=20, col_offset=15, end_lineno=20, end_col_offset=19, id='self', ctx=Load()),
#                                         attr='B',
#                                         ctx=Load(),
#                                     ),
#                                     args=[],
#                                     keywords=[],
#                                 ),
#                                 op=Add(),
#                                 right=Call(
#                                     lineno=20,
#                                     col_offset=26,
#                                     end_lineno=20,
#                                     end_col_offset=34,
#                                     func=Attribute(
#                                         lineno=20,
#                                         col_offset=26,
#                                         end_lineno=20,
#                                         end_col_offset=32,
#                                         value=Name(lineno=20, col_offset=26, end_lineno=20, end_col_offset=30, id='self', ctx=Load()),
#                                         attr='A',
#                                         ctx=Load(),
#                                     ),
#                                     args=[],
#                                     keywords=[],
#                                 ),
#                             ),
#                         ),
#                     ],
#                     decorator_list=[
#                         Call(
#                             lineno=17,
#                             col_offset=5,
#                             end_lineno=17,
#                             end_col_offset=17,
#                             func=Name(lineno=17, col_offset=5, end_lineno=17, end_col_offset=15, id='graph_node', ctx=Load()),
#                             args=[],
#                             keywords=[],
#                         ),
#                     ],
#                     returns=None,
#                     type_comment=None,
#                 ),
#                 FunctionDef(
#                     lineno=23,
#                     col_offset=4,
#                     end_lineno=25,
#                     end_col_offset=29,
#                     name='D',
#                     args=arguments(
#                         posonlyargs=[],
#                         args=[
#                             arg(lineno=23, col_offset=10, end_lineno=23, end_col_offset=14, arg='self', annotation=None, type_comment=None),
#                             arg(lineno=23, col_offset=16, end_lineno=23, end_col_offset=21, arg='value', annotation=None, type_comment=None),
#                         ],
#                         vararg=None,
#                         kwonlyargs=[],
#                         kw_defaults=[],
#                         kwarg=None,
#                         defaults=[],
#                     ),
#                     body=[
#                         Expr(
#                             lineno=24,
#                             col_offset=8,
#                             end_lineno=24,
#                             end_col_offset=53,
#                             value=Call(
#                                 lineno=24,
#                                 col_offset=8,
#                                 end_lineno=24,
#                                 end_col_offset=53,
#                                 func=Attribute(
#                                     lineno=24,
#                                     col_offset=8,
#                                     end_lineno=24,
#                                     end_col_offset=20,
#                                     value=Name(lineno=24, col_offset=8, end_lineno=24, end_col_offset=14, id='logger', ctx=Load()),
#                                     attr='debug',
#                                     ctx=Load(),
#                                 ),
#                                 args=[Constant(lineno=24, col_offset=21, end_lineno=24, end_col_offset=52, value='[MyGraph] graph_node D called', kind=None)],
#                                 keywords=[],
#                             ),
#                         ),
#                         Return(
#                             lineno=25,
#                             col_offset=8,
#                             end_lineno=25,
#                             end_col_offset=29,
#                             value=BinOp(
#                                 lineno=25,
#                                 col_offset=15,
#                                 end_lineno=25,
#                                 end_col_offset=29,
#                                 left=Name(lineno=25, col_offset=15, end_lineno=25, end_col_offset=20, id='value', ctx=Load()),
#                                 op=Mult(),
#                                 right=Call(
#                                     lineno=25,
#                                     col_offset=21,
#                                     end_lineno=25,
#                                     end_col_offset=29,
#                                     func=Attribute(
#                                         lineno=25,
#                                         col_offset=21,
#                                         end_lineno=25,
#                                         end_col_offset=27,
#                                         value=Name(lineno=25, col_offset=21, end_lineno=25, end_col_offset=25, id='self', ctx=Load()),
#                                         attr='B',
#                                         ctx=Load(),
#                                     ),
#                                     args=[],
#                                     keywords=[],
#                                 ),
#                             ),
#                         ),
#                     ],
#                     decorator_list=[
#                         Call(
#                             lineno=22,
#                             col_offset=5,
#                             end_lineno=22,
#                             end_col_offset=17,
#                             func=Name(lineno=22, col_offset=5, end_lineno=22, end_col_offset=15, id='graph_node', ctx=Load()),
#                             args=[],
#                             keywords=[],
#                         ),
#                     ],
#                     returns=None,
#                     type_comment=None,
#                 ),
#                 FunctionDef(
#                     lineno=28,
#                     col_offset=4,
#                     end_lineno=30,
#                     end_col_offset=37,
#                     name='E',
#                     args=arguments(
#                         posonlyargs=[],
#                         args=[arg(lineno=28, col_offset=10, end_lineno=28, end_col_offset=14, arg='self', annotation=None, type_comment=None)],
#                         vararg=None,
#                         kwonlyargs=[],
#                         kw_defaults=[],
#                         kwarg=None,
#                         defaults=[],
#                     ),
#                     body=[
#                         Expr(
#                             lineno=29,
#                             col_offset=8,
#                             end_lineno=29,
#                             end_col_offset=53,
#                             value=Call(
#                                 lineno=29,
#                                 col_offset=8,
#                                 end_lineno=29,
#                                 end_col_offset=53,
#                                 func=Attribute(
#                                     lineno=29,
#                                     col_offset=8,
#                                     end_lineno=29,
#                                     end_col_offset=20,
#                                     value=Name(lineno=29, col_offset=8, end_lineno=29, end_col_offset=14, id='logger', ctx=Load()),
#                                     attr='debug',
#                                     ctx=Load(),
#                                 ),
#                                 args=[Constant(lineno=29, col_offset=21, end_lineno=29, end_col_offset=52, value='[MyGraph] graph_node E called', kind=None)],
#                                 keywords=[],
#                             ),
#                         ),
#                         Return(
#                             lineno=30,
#                             col_offset=8,
#                             end_lineno=30,
#                             end_col_offset=37,
#                             value=BinOp(
#                                 lineno=30,
#                                 col_offset=15,
#                                 end_lineno=30,
#                                 end_col_offset=37,
#                                 left=Call(
#                                     lineno=30,
#                                     col_offset=15,
#                                     end_lineno=30,
#                                     end_col_offset=33,
#                                     func=Attribute(
#                                         lineno=30,
#                                         col_offset=15,
#                                         end_lineno=30,
#                                         end_col_offset=21,
#                                         value=Name(lineno=30, col_offset=15, end_lineno=30, end_col_offset=19, id='self', ctx=Load()),
#                                         attr='D',
#                                         ctx=Load(),
#                                     ),
#                                     args=[
#                                         Call(
#                                             lineno=30,
#                                             col_offset=23,
#                                             end_lineno=30,
#                                             end_col_offset=31,
#                                             func=Attribute(
#                                                 lineno=30,
#                                                 col_offset=23,
#                                                 end_lineno=30,
#                                                 end_col_offset=29,
#                                                 value=Name(lineno=30, col_offset=23, end_lineno=30, end_col_offset=27, id='self', ctx=Load()),
#                                                 attr='A',
#                                                 ctx=Load(),
#                                             ),
#                                             args=[],
#                                             keywords=[],
#                                         ),
#                                     ],
#                                     keywords=[],
#                                 ),
#                                 op=Mult(),
#                                 right=Constant(lineno=30, col_offset=36, end_lineno=30, end_col_offset=37, value=2, kind=None),
#                             ),
#                         ),
#                     ],
#                     decorator_list=[
#                         Call(
#                             lineno=27,
#                             col_offset=5,
#                             end_lineno=27,
#                             end_col_offset=17,
#                             func=Name(lineno=27, col_offset=5, end_lineno=27, end_col_offset=15, id='graph_node', ctx=Load()),
#                             args=[],
#                             keywords=[],
#                         ),
#                     ],
#                     returns=None,
#                     type_comment=None,
#                 ),
#                 FunctionDef(
#                     lineno=33,
#                     col_offset=4,
#                     end_lineno=38,
#                     end_col_offset=21,
#                     name='F',
#                     args=arguments(
#                         posonlyargs=[],
#                         args=[arg(lineno=33, col_offset=10, end_lineno=33, end_col_offset=14, arg='self', annotation=None, type_comment=None)],
#                         vararg=None,
#                         kwonlyargs=[],
#                         kw_defaults=[],
#                         kwarg=None,
#                         defaults=[],
#                     ),
#                     body=[
#                         Expr(
#                             lineno=34,
#                             col_offset=8,
#                             end_lineno=34,
#                             end_col_offset=53,
#                             value=Call(
#                                 lineno=34,
#                                 col_offset=8,
#                                 end_lineno=34,
#                                 end_col_offset=53,
#                                 func=Attribute(
#                                     lineno=34,
#                                     col_offset=8,
#                                     end_lineno=34,
#                                     end_col_offset=20,
#                                     value=Name(lineno=34, col_offset=8, end_lineno=34, end_col_offset=14, id='logger', ctx=Load()),
#                                     attr='debug',
#                                     ctx=Load(),
#                                 ),
#                                 args=[Constant(lineno=34, col_offset=21, end_lineno=34, end_col_offset=52, value='[MyGraph] graph_node F called', kind=None)],
#                                 keywords=[],
#                             ),
#                         ),
#                         If(
#                             lineno=35,
#                             col_offset=8,
#                             end_lineno=38,
#                             end_col_offset=21,
#                             test=Compare(
#                                 lineno=35,
#                                 col_offset=11,
#                                 end_lineno=35,
#                                 end_col_offset=23,
#                                 left=Call(
#                                     lineno=35,
#                                     col_offset=11,
#                                     end_lineno=35,
#                                     end_col_offset=19,
#                                     func=Attribute(
#                                         lineno=35,
#                                         col_offset=11,
#                                         end_lineno=35,
#                                         end_col_offset=17,
#                                         value=Name(lineno=35, col_offset=11, end_lineno=35, end_col_offset=15, id='self', ctx=Load()),
#                                         attr='A',
#                                         ctx=Load(),
#                                     ),
#                                     args=[],
#                                     keywords=[],
#                                 ),
#                                 ops=[Gt()],
#                                 comparators=[Constant(lineno=35, col_offset=22, end_lineno=35, end_col_offset=23, value=5, kind=None)],
#                             ),
#                             body=[
#                                 Return(
#                                     lineno=36,
#                                     col_offset=12,
#                                     end_lineno=36,
#                                     end_col_offset=31,
#                                     value=BinOp(
#                                         lineno=36,
#                                         col_offset=19,
#                                         end_lineno=36,
#                                         end_col_offset=31,
#                                         left=Call(
#                                             lineno=36,
#                                             col_offset=19,
#                                             end_lineno=36,
#                                             end_col_offset=27,
#                                             func=Attribute(
#                                                 lineno=36,
#                                                 col_offset=19,
#                                                 end_lineno=36,
#                                                 end_col_offset=25,
#                                                 value=Name(lineno=36, col_offset=19, end_lineno=36, end_col_offset=23, id='self', ctx=Load()),
#                                                 attr='E',
#                                                 ctx=Load(),
#                                             ),
#                                             args=[],
#                                             keywords=[],
#                                         ),
#                                         op=Mult(),
#                                         right=Constant(lineno=36, col_offset=28, end_lineno=36, end_col_offset=31, value=1.5, kind=None),
#                                     ),
#                                 ),
#                             ],
#                             orelse=[
#                                 Return(
#                                     lineno=38,
#                                     col_offset=12,
#                                     end_lineno=38,
#                                     end_col_offset=21,
#                                     value=Constant(lineno=38, col_offset=19, end_lineno=38, end_col_offset=21, value=14, kind=None),
#                                 ),
#                             ],
#                         ),
#                     ],
#                     decorator_list=[
#                         Call(
#                             lineno=32,
#                             col_offset=5,
#                             end_lineno=32,
#                             end_col_offset=17,
#                             func=Name(lineno=32, col_offset=5, end_lineno=32, end_col_offset=15, id='graph_node', ctx=Load()),
#                             args=[],
#                             keywords=[],
#                         ),
#                     ],
#                     returns=None,
#                     type_comment=None,
#                 ),
#             ],
#             decorator_list=[],
#         ),
#     ],
#     type_ignores=[],
# )

# %%
import astpretty

# %%
from graphviz import Digraph
import pprint

# %%
def build_graph(node, graph=None, parent=None):
    if graph is None:
        graph = Digraph()
    node_id = str(id(node))
    
    label_pre = ''
    if isinstance(node, ast.FunctionDef):
        label_pre = f'def {node.name}()'
    if isinstance(node, ast.Attribute):
        if hasattr(node.value, 'id'):
            label_pre = f'{node.value.id}.{node.attr}'
        else:
            label_pre = {node.attr}
    label = f'{label_pre}_{type(node).__name__}' if label_pre else type(node).__name__
    
    graph.node(node_id, label)
    if parent:
        graph.edge(parent, node_id)

    for child in ast.iter_child_nodes(node):
        build_graph(child, graph, node_id)
    return graph

# source_code = "x = a + b"
# tree = ast.parse(source_code)

dot = build_graph(tree)
dot.render("ast_tree", format="png", cleanup=True)  # creates ast_tree.pn
# Out:
# 2025-08-11 00:30:30.952India Standard Time 31684 DEBUG write lines to 'ast_tree'
# 2025-08-11 00:30:30.957India Standard Time 31684 DEBUG run [WindowsPath('dot'), '-Kdot', '-Tpng', '-O', 'ast_tree']
# 2025-08-11 00:30:31.730India Standard Time 31684 DEBUG delete 'ast_tree'
# 'ast_tree.png'

# %%
type(b).__name__
# Out:
# 'FunctionDef'
